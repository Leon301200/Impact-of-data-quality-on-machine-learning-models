# %%
import pandas as pd

# %%
data = pd.read_csv('../../Data/Clustering/retail Data/retail_data.csv')
data
# Out:
#         Transaction_ID  Customer_ID                 Name  \
# 0            8691788.0      37249.0  Michelle Harrington
# 1            2174773.0      69749.0          Kelsey Hill
# 2            6679610.0      30192.0         Scott Jensen
# 3            7232460.0      62101.0        Joseph Miller
# 4            4983775.0      27901.0        Debra Coleman
# ...                ...          ...                  ...
# 302005       4246475.0      12104.0         Meagan Ellis
# 302006       1197603.0      69772.0          Mathew Beck
# 302007       7743242.0      28449.0           Daniel Lee
# 302008       9301950.0      45477.0       Patrick Wilson
# 302009       2882826.0      53626.0       Dustin Merritt
#
#                            Email         Phone                       Address  \
# 0              Ebony39@gmail.com  1.414787e+09             3959 Amanda Burgs
# 1               Mark36@gmail.com  6.852900e+09            82072 Dawn Centers
# ...

# %%
# Supprimer les lignes avec au moins une valeur manquante
df = data.dropna()
df
# Out:
#         Transaction_ID  Customer_ID                 Name  \
# 0            8691788.0      37249.0  Michelle Harrington
# 1            2174773.0      69749.0          Kelsey Hill
# 2            6679610.0      30192.0         Scott Jensen
# 3            7232460.0      62101.0        Joseph Miller
# 4            4983775.0      27901.0        Debra Coleman
# ...                ...          ...                  ...
# 302005       4246475.0      12104.0         Meagan Ellis
# 302006       1197603.0      69772.0          Mathew Beck
# 302007       7743242.0      28449.0           Daniel Lee
# 302008       9301950.0      45477.0       Patrick Wilson
# 302009       2882826.0      53626.0       Dustin Merritt
#
#                            Email         Phone                       Address  \
# 0              Ebony39@gmail.com  1.414787e+09             3959 Amanda Burgs
# 1               Mark36@gmail.com  6.852900e+09            82072 Dawn Centers
# ...

# %%
df = df.drop('Transaction_ID',axis=1)
df = df.drop('Customer_ID', axis=1)
df = df.drop('Name', axis=1)
df = df.drop('Email', axis=1)
df = df.drop('Phone', axis=1)
df = df.drop('Address', axis=1)
df = df.drop('Month', axis=1)
df = df.drop('Year', axis=1)
# df = df.drop('products', axis=1)
# df = df.drop('Product_Brand', axis=1)
df = df.drop('Time', axis=1)
df['Zipcode'] = df['Zipcode'].astype(str)

# %%
# Fonction pour convertir une date dans le bon format
def parse_date(date_str):
    formats = ['%d-%m-%y', '%m/%d/%Y']
    for fmt in formats:
        try:
            return pd.to_datetime(date_str, format=fmt)
        except ValueError:
            continue
    return pd.NaT  # Si aucun format ne correspond

# df['date'] = pd.to_datetime(df['Date'], dayfirst=True, errors='coerce')
df['Date'] = df['Date'].apply(parse_date)

# Extraire le jour, le mois et l'année
df['Day'] = df['Date'].dt.day
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year

df = df.drop('Date', axis=1)
df[['Day','Month','Year']]
# Out:
#         Day  Month  Year
# 0        18      9  2023
# 1        31     12  2023
# 2        26      4  2023
# 3         5      8  2023
# 4         1     10  2024
# ...     ...    ...   ...
# 302005   20      1  2024
# 302006   28     12  2023
# 302007   27      2  2024
# 302008    9      3  2023
# 302009    1      8  2024
#
# [293911 rows x 3 columns]

# %%
## One Hot Encoding
# object_columns = df.select_dtypes(include=['object']).columns
# df = pd.get_dummies(df, columns=object_columns)
# df

# %%
df.to_csv('../../Data/Clustering/retail Data/retail_data_clean.csv', index=False)
print('DataSet enregistré')
df
# Out:
# DataSet enregistré
#               City            State  Zipcode    Country   Age  Gender  Income  \
# 0         Dortmund           Berlin  77985.0    Germany  21.0    Male     Low
# 1       Nottingham          England  99071.0         UK  19.0  Female     Low
# 2          Geelong  New South Wales  75929.0  Australia  48.0    Male     Low
# 3         Edmonton          Ontario  88420.0     Canada  56.0    Male    High
# 4          Bristol          England  48704.0         UK  22.0    Male     Low
# ...            ...              ...      ...        ...   ...     ...     ...
# 302005  Townsville  New South Wales   4567.0  Australia  31.0    Male  Medium
# 302006     Hanover           Berlin  16852.0    Germany  35.0  Female     Low
# 302007    Brighton          England  88038.0         UK  41.0    Male     Low
# 302008     Halifax          Ontario  67608.0     Canada  41.0    Male  Medium
# 302009      Tucson    West Virginia  25242.0        USA  28.0  Female     Low
#
# ...
