# %%
import pandas as pd
from imputation_strategies import impute_numerical_mean, impute_numerical_median, impute_numerical_knn, impute_numerical_multiple, impute_numerical_decision_tree, impute_categorical_mode, impute_categorical_new_category, impute_categorical_decision_tree
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[29], line 2
#       1 import pandas as pd
# ----> 2 from imputation_strategies import impute_numerical_mean, impute_numerical_median, impute_numerical_knn, impute_numerical_multiple, impute_numerical_decision_tree, impute_categorical_mode, impute_categorical_new_category, impute_categorical_decision_tree
#
# ImportError: cannot import name 'impute_numerical_decision_tree' from 'imputation_strategies' (/Users/leon/Documents/Impact-of-data-quality-on-machine-learning-models/Code/Data quality dimension/Completeness/imputation_strategies.py)

# %%
df = pd.read_csv('../../../Data/Classification/Indicators of Heart Disease/Completeness/NaN/heart_2022_10%.csv')
df
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 0              Alabama  Female     Very good                 4.0
# 1              Alabama    Male     Very good                 0.0
# 2                  NaN    Male     Very good                 0.0
# 3              Alabama  Female          Fair                 5.0
# 4              Alabama  Female          Good                 3.0
# ...                ...     ...           ...                 ...
# 246017  Virgin Islands    Male     Very good                 0.0
# 246018  Virgin Islands  Female          Fair                 0.0
# 246019  Virgin Islands    Male          Good                 0.0
# 246020  Virgin Islands  Female     Excellent                 2.0
# 246021  Virgin Islands    Male     Very good                 0.0
#
#         MentalHealthDays                                    LastCheckupTime  \
# 0                    0.0  Within past year (anytime less than 12 months ...
# ...

# %%
df_mean = impute_numerical_mean(df.copy())
df_mean
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 0              Alabama  Female     Very good                 4.0
# 1              Alabama    Male     Very good                 0.0
# 2                  NaN    Male     Very good                 0.0
# 3              Alabama  Female          Fair                 5.0
# 4              Alabama  Female          Good                 3.0
# ...                ...     ...           ...                 ...
# 246017  Virgin Islands    Male     Very good                 0.0
# 246018  Virgin Islands  Female          Fair                 0.0
# 246019  Virgin Islands    Male          Good                 0.0
# 246020  Virgin Islands  Female     Excellent                 2.0
# 246021  Virgin Islands    Male     Very good                 0.0
#
#         MentalHealthDays                                    LastCheckupTime  \
# 0                    0.0  Within past year (anytime less than 12 months ...
# ...

# %%
df_median = impute_numerical_median(df.copy())
df_median
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 0              Alabama  Female     Very good                 4.0
# 1              Alabama    Male     Very good                 0.0
# 2                  NaN    Male     Very good                 0.0
# 3              Alabama  Female          Fair                 5.0
# 4              Alabama  Female          Good                 3.0
# ...                ...     ...           ...                 ...
# 246017  Virgin Islands    Male     Very good                 0.0
# 246018  Virgin Islands  Female          Fair                 0.0
# 246019  Virgin Islands    Male          Good                 0.0
# 246020  Virgin Islands  Female     Excellent                 2.0
# 246021  Virgin Islands    Male     Very good                 0.0
#
#         MentalHealthDays                                    LastCheckupTime  \
# 0                    0.0  Within past year (anytime less than 12 months ...
# ...

# %%
df_knn = impute_numerical_knn(df.copy())
df_knn
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 0              Alabama  Female     Very good                 4.0
# 1              Alabama    Male     Very good                 0.0
# 2                  NaN    Male     Very good                 0.0
# 3              Alabama  Female          Fair                 5.0
# 4              Alabama  Female          Good                 3.0
# ...                ...     ...           ...                 ...
# 246017  Virgin Islands    Male     Very good                 0.0
# 246018  Virgin Islands  Female          Fair                 0.0
# 246019  Virgin Islands    Male          Good                 0.0
# 246020  Virgin Islands  Female     Excellent                 2.0
# 246021  Virgin Islands    Male     Very good                 0.0
#
#         MentalHealthDays                                    LastCheckupTime  \
# 0                    0.0  Within past year (anytime less than 12 months ...
# ...

# %%
df_multiple = impute_numerical_multiple(df.copy())
df_multiple
# Out:
# /opt/anaconda3/envs/Impact-of-data-quality-on-machine-learning-models/lib/python3.11/site-packages/sklearn/impute/_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 0              Alabama  Female     Very good                 4.0
# 1              Alabama    Male     Very good                 0.0
# 2                  NaN    Male     Very good                 0.0
# 3              Alabama  Female          Fair                 5.0
# 4              Alabama  Female          Good                 3.0
# ...                ...     ...           ...                 ...
# 246017  Virgin Islands    Male     Very good                 0.0
# 246018  Virgin Islands  Female          Fair                 0.0
# 246019  Virgin Islands    Male          Good                 0.0
# 246020  Virgin Islands  Female     Excellent                 2.0
# ...

# %%
df_random_forest = impute_numerical_decision_tree(df.copy())
df_random_forest
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 0              Alabama  Female     Very good                 4.0
# 1              Alabama    Male     Very good                 0.0
# 2                  NaN    Male     Very good                 0.0
# 3              Alabama  Female          Fair                 5.0
# 4              Alabama  Female          Good                 3.0
# ...                ...     ...           ...                 ...
# 246017  Virgin Islands    Male     Very good                 0.0
# 246018  Virgin Islands  Female          Fair                 0.0
# 246019  Virgin Islands    Male          Good                 0.0
# 246020  Virgin Islands  Female     Excellent                 2.0
# 246021  Virgin Islands    Male     Very good                 0.0
#
#         MentalHealthDays                                    LastCheckupTime  \
# 0                    0.0  Within past year (anytime less than 12 months ...
# ...

# %%
df_mode = impute_categorical_mode(df.copy())
df_mode
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 0              Alabama  Female     Very good                 4.0
# 1              Alabama    Male     Very good                 0.0
# 2           Washington    Male     Very good                 0.0
# 3              Alabama  Female          Fair                 5.0
# 4              Alabama  Female          Good                 3.0
# ...                ...     ...           ...                 ...
# 246017  Virgin Islands    Male     Very good                 0.0
# 246018  Virgin Islands  Female          Fair                 0.0
# 246019  Virgin Islands    Male          Good                 0.0
# 246020  Virgin Islands  Female     Excellent                 2.0
# 246021  Virgin Islands    Male     Very good                 0.0
#
#         MentalHealthDays                                    LastCheckupTime  \
# 0                    0.0  Within past year (anytime less than 12 months ...
# ...

# %%
df_new_category = impute_categorical_new_category(df.copy())
df_new_category
# Out:
#                  State     Sex GeneralHealth PhysicalHealthDays  \
# 0              Alabama  Female     Very good                4.0
# 1              Alabama    Male     Very good                0.0
# 2              Missing    Male     Very good                0.0
# 3              Alabama  Female          Fair                5.0
# 4              Alabama  Female          Good                3.0
# ...                ...     ...           ...                ...
# 246017  Virgin Islands    Male     Very good                0.0
# 246018  Virgin Islands  Female          Fair                0.0
# 246019  Virgin Islands    Male          Good                0.0
# 246020  Virgin Islands  Female     Excellent                2.0
# 246021  Virgin Islands    Male     Very good                0.0
#
#        MentalHealthDays                                    LastCheckupTime  \
# 0                   0.0  Within past year (anytime less than 12 months ...
# ...

# %%
df_categorical_decision_tree = impute_categorical_decision_tree(df.copy())
df_categorical_decision_tree
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df_classification = impute_categorical_decision_tree(df.copy())
#       2 df_classification
#
# NameError: name 'impute_categorical_decision_tree' is not defined

# %%
# df_hot_deck = impute_by_hot_deck(df.copy())
# df_hot_deck

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 30
#      27     return df_imputed
#      29 # Exemple d'utilisation :
# ---> 30 df_imputed = impute_by_knn(df.copy(), n_neighbors=5)
#
# Cell In[39], line 25, in impute_by_knn(df, n_neighbors)
#      23 # Reconversion des colonnes catégoriques encodées en leurs valeurs d'origine
#      24 for column, oe in ordinal_encoders.items():
# ---> 25     df_imputed[column] = oe.inverse_transform(df_imputed[[column]])
#      27 return df_imputed
#
# File /opt/anaconda3/envs/Impact-of-data-quality-on-machine-learning-models/lib/python3.11/site-packages/pandas/core/frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# ...
